# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
data= pd.read_csv("fifa_eda.csv")

# %%
data.head(10)
# Out:
#        ID               Name  Age Nationality  Overall  Potential  \
# 0  158023           L. Messi   31   Argentina       94         94
# 1   20801  Cristiano Ronaldo   33    Portugal       94         94
# 2  190871          Neymar Jr   26      Brazil       92         93
# 3  193080             De Gea   27       Spain       91         93
# 4  192985       K. De Bruyne   27     Belgium       91         92
# 5  183277          E. Hazard   27     Belgium       91         91
# 6  177003          L. Modrić   32     Croatia       91         91
# 7  176580          L. Suárez   31     Uruguay       91         91
# 8  155862       Sergio Ramos   32       Spain       91         91
# 9  200389           J. Oblak   25    Slovenia       90         93
#
#                   Club     Value   Wage Preferred Foot  \
# 0         FC Barcelona  110500.0  565.0           Left
# 1             Juventus   77000.0  405.0          Right
# 2  Paris Saint-Germain  118500.0  290.0          Right
# ...

# %%
data.tail(10)
# Out:
#            ID                Name  Age          Nationality  Overall  \
# 18197  246167          D. Holland   18  Republic of Ireland       47
# 18198  242844          J. Livesey   18              England       47
# 18199  244677        M. Baldisimo   18               Canada       47
# 18200  231381            J. Young   18             Scotland       47
# 18201  243413            D. Walsh   18  Republic of Ireland       47
# 18202  238813        J. Lundstram   19              England       47
# 18203  243165  N. Christoffersson   19               Sweden       47
# 18204  241638           B. Worman   16              England       47
# 18205  246268      D. Walker-Rice   17              England       47
# 18206  246269           G. Nugent   16              England       46
#
#        Potential                    Club  Value  Wage Preferred Foot  \
# 18197         61               Cork City   60.0   1.0          Right
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18207 entries, 0 to 18206
# Data columns (total 18 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ID                        18207 non-null  int64
#  1   Name                      18207 non-null  object
#  2   Age                       18207 non-null  int64
#  3   Nationality               18207 non-null  object
#  4   Overall                   18207 non-null  int64
#  5   Potential                 18207 non-null  int64
#  6   Club                      17966 non-null  object
#  7   Value                     17955 non-null  float64
#  8   Wage                      18207 non-null  float64
#  9   Preferred Foot            18207 non-null  object
#  10  International Reputation  18159 non-null  float64
#  11  Skill Moves               18159 non-null  float64
#  12  Position                  18207 non-null  object
# ...

# %%
data.columns
# Out:
# Index(['ID', 'Name', 'Age', 'Nationality', 'Overall', 'Potential', 'Club',
#        'Value', 'Wage', 'Preferred Foot', 'International Reputation',
#        'Skill Moves', 'Position', 'Joined', 'Contract Valid Until', 'Height',
#        'Weight', 'Release Clause'],
#       dtype='object')

# %%
data.shape
# Out:
# (18207, 18)

# %%
data.describe()
# Out:
#                   ID           Age       Overall     Potential          Value  \
# count   18207.000000  18207.000000  18207.000000  18207.000000   17955.000000
# mean   214298.338606     25.122206     66.238699     71.307299    2444.530214
# std     29965.244204      4.669943      6.908930      6.136496    5626.715434
# min        16.000000     16.000000     46.000000     48.000000      10.000000
# 25%    200315.500000     21.000000     62.000000     67.000000     325.000000
# 50%    221759.000000     25.000000     66.000000     71.000000     700.000000
# 75%    236529.500000     28.000000     71.000000     75.000000    2100.000000
# max    246620.000000     45.000000     94.000000     95.000000  118500.000000
#
#                Wage  International Reputation   Skill Moves        Joined  \
# count  18207.000000              18159.000000  18159.000000  18207.000000
# mean       9.731312                  1.113222      2.361308   2016.420607
# ...

# %%
data.isnull().sum()
# Out:
# ID                            0
# Name                          0
# Age                           0
# Nationality                   0
# Overall                       0
# Potential                     0
# Club                        241
# Value                       252
# Wage                          0
# Preferred Foot                0
# International Reputation     48
# Skill Moves                  48
# Position                      0
# Joined                        0
# Contract Valid Until        289
# Height                        0
# Weight                        0
# Release Clause                0
# dtype: int64

# %%
data.sample(3)
# Out:
#            ID            Name  Age Nationality  Overall  Potential  \
# 9337   172928        C. Lines   32     England       66         66
# 10799  235990  Markel Areitio   21       Spain       65         77
# 16798  242276     Wang Ziming   21    China PR       56         65
#
#                           Club  Value  Wage Preferred Foot  \
# 9337            Bristol Rovers  475.0   4.0          Right
# 10799                 SD Eibar  775.0   3.0          Right
# 16798  Beijing Sinobo Guoan FC  140.0   2.0          Right
#
#        International Reputation  Skill Moves Position  Joined  \
# 9337                        1.0          3.0       CM    2015
# 10799                       1.0          1.0       GK    2016
# 16798                       1.0          2.0       ST    2017
#
#       Contract Valid Until    Height  Weight  Release Clause
# 9337            2019-01-01  6.166667   174.0           831.0
# 10799           2019-01-01  5.916667   152.0          1800.0
# ...

# %%
from sklearn.impute import SimpleImputer

# %%
data['International Reputation'].fillna(method='ffill' , inplace = True)

# %%
data.isnull().sum()
# Out:
# ID                            0
# Name                          0
# Age                           0
# Nationality                   0
# Overall                       0
# Potential                     0
# Club                        241
# Value                       252
# Wage                          0
# Preferred Foot                0
# International Reputation      0
# Skill Moves                  48
# Position                      0
# Joined                        0
# Contract Valid Until        289
# Height                        0
# Weight                        0
# Release Clause                0
# dtype: int64

# %%
data.dropna(subset=['Club', 'Contract Valid Until'], inplace= True)

# %%
data['Value'].fillna(value=data['Value'].mode(), inplace = True)

# %%
data[data['Value'].isnull()]
# Out:
#            ID           Name  Age        Nationality  Overall  Potential  \
# 864    153260         Hilton   40             Brazil       78         78
# 3550    29552    S. Nakamura   40              Japan       72         72
# 4228     3665       B. Nivet   41             France       71         71
# 10356   49511       F. Kippe   40             Norway       65         65
# 12192  208927   H. Sulaimani   41       Saudi Arabia       63         63
# 12453  214372        W. Díaz   40           Colombia       63         63
# 14129  156480    Y. Nakazawa   40              Japan       61         61
# 17672  237744       R. Kawai   39              Japan       53         53
# 17726   51963      T. Warner   44  Trinidad & Tobago       53         53
# 17752  100899    S. Phillips   40            England       52         52
# 18183   53748  K. Pilkington   44            England       48         48
#
#                              Club  Value  Wage Preferred Foot  \
# ...

# %%
data.dropna(subset=['Value'] , inplace = True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17907 entries, 0 to 18206
# Data columns (total 18 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ID                        17907 non-null  int64
#  1   Name                      17907 non-null  object
#  2   Age                       17907 non-null  int64
#  3   Nationality               17907 non-null  object
#  4   Overall                   17907 non-null  int64
#  5   Potential                 17907 non-null  int64
#  6   Club                      17907 non-null  object
#  7   Value                     17907 non-null  float64
#  8   Wage                      17907 non-null  float64
#  9   Preferred Foot            17907 non-null  object
#  10  International Reputation  17907 non-null  float64
#  11  Skill Moves               17907 non-null  float64
#  12  Position                  17907 non-null  object
# ...

# %%
data.sample(5)
# Out:
#            ID              Name  Age     Nationality  Overall  Potential  \
# 8226   214661        G. Iñíguez   24       Argentina       67         72
# 14884  226140         D. Chávez   23          Mexico       60         64
# 15065  212133      A. Hollingen   23          Norway       60         64
# 3761   183220        J. Morávek   28  Czech Republic       72         72
# 166    212523  Anderson Talisca   24          Brazil       83         90
#
#                                  Club    Value  Wage Preferred Foot  \
# 8226                          Udinese   1000.0   8.0          Right
# 14884     Tiburones Rojos de Veracruz    270.0   1.0          Right
# 15065                        IK Start    270.0   1.0          Right
# 3761                      FC Augsburg   3100.0  18.0          Right
# 166    Guangzhou Evergrande Taobao FC  36500.0  18.0           Left
#
#        International Reputation  Skill Moves Position  Joined  \
# ...

# %%
# df["InsertedDate"] = pd.to_datetime(df["InsertedDate"])
# df["InsertedDates"] =  pd.to_datetime(df["InsertedDates"], format="%Y/%m/%d")

# %%
sns.scatterplot(data=data , x='Age',y='Release Clause',sizes=(50,300) ,palette='plasma')

# %%
sns.scatterplot(data=data , x='Position',y='International Reputation',sizes=(50,300) ,palette='Purples')

# %%
data["Contract Valid Until"] = data["Contract Valid Until"].astype('datetime64[ns]')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17907 entries, 0 to 18206
# Data columns (total 18 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ID                        17907 non-null  int64
#  1   Name                      17907 non-null  object
#  2   Age                       17907 non-null  int64
#  3   Nationality               17907 non-null  object
#  4   Overall                   17907 non-null  int64
#  5   Potential                 17907 non-null  int64
#  6   Club                      17907 non-null  object
#  7   Value                     17907 non-null  float64
#  8   Wage                      17907 non-null  float64
#  9   Preferred Foot            17907 non-null  object
#  10  International Reputation  17907 non-null  float64
#  11  Skill Moves               17907 non-null  float64
#  12  Position                  17907 non-null  object
# ...

# %%
sns.boxplot(data['Height'])

# %%
sns.boxplot(data['Weight'])

# %%
sns.boxplot(data['Value'])

# %%
data.sample(3)
# Out:
#            ID        Name  Age Nationality  Overall  Potential  \
# 14688  240399  J. Montaño   25    Colombia       60         65
# 2243   116308    R. Fanni   36      France       74         74
# 6603   202238     Muralha   25      Brazil       69         71
#
#                     Club   Value  Wage Preferred Foot  \
# 14688  Alianza Petrolera   230.0   1.0          Right
# 2243     Montreal Impact   750.0   5.0          Right
# 6603            Al Hazem  1300.0   6.0          Right
#
#        International Reputation  Skill Moves Position  Joined  \
# 14688                       1.0          2.0       RB    2018
# 2243                        2.0          2.0      RCB    2018
# 6603                        1.0          3.0      LDM    2018
#
#       Contract Valid Until    Height  Weight  Release Clause
# 14688           2021-01-01  5.583333   152.0           328.0
# 2243            2018-01-01  6.083333   179.0          1100.0
# ...

# %%
data['Nationality'].value_counts()
# Out:
# England      1655
# Germany      1195
# Spain        1071
# Argentina     935
# France        910
#              ...
# Palestine       1
# Kuwait          1
# St Lucia        1
# Botswana        1
# Malta           1
# Name: Nationality, Length: 163, dtype: int64

# %%
data['Nationality'].value_counts().count()
# Out:
# 163

# %%
data.shape
# Out:
# (17907, 18)

# %%
data['Club'].value_counts()
# Out:
# Newcastle United             33
# Liverpool                    33
# Manchester City              33
# Manchester United            33
# Real Madrid                  33
#                              ..
# América FC (Minas Gerais)    20
# Vitória                      20
# Sligo Rovers                 19
# Limerick FC                  19
# Derry City                   18
# Name: Club, Length: 651, dtype: int64

# %%
data['International Reputation'].value_counts()
# Out:
# 1.0    16298
# 2.0     1245
# 3.0      307
# 4.0       51
# 5.0        6
# Name: International Reputation, dtype: int64

# %%
data['Position'].value_counts()
# Out:
# ST     2130
# GK     1989
# CB     1751
# CM     1377
# LB     1304
# RB     1268
# RM     1114
# LM     1086
# CAM     946
# CDM     936
# RCB     652
# LCB     635
# LCM     389
# RCM     387
# LW      374
# RW      365
# RDM     246
# LDM     239
# LS      206
# RS      201
# RWB      87
# LWB      78
# CF       74
# LAM      21
# RAM      21
# RF       16
# LF       15
# Name: Position, dtype: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data2=pd.get_dummies(data['Preferred Foot'])
data2
# Out:
#        Left  Right
# 0         1      0
# 1         0      1
# 2         0      1
# 3         0      1
# 4         0      1
# ...     ...    ...
# 18202     0      1
# 18203     0      1
# 18204     0      1
# 18205     0      1
# 18206     0      1
#
# [17907 rows x 2 columns]

# %%
pd.get_dummies(data['Preferred Foot'],drop_first=True)
# Out:
#        Right
# 0          0
# 1          1
# 2          1
# 3          1
# 4          1
# ...      ...
# 18202      1
# 18203      1
# 18204      1
# 18205      1
# 18206      1
#
# [17907 rows x 1 columns]

# %%
data= pd.concat([data, data2], axis=1, join="outer")

# %%
data.head(10)
# Out:
#        ID               Name  Age Nationality  Overall  Potential  \
# 0  158023           L. Messi   31   Argentina       94         94
# 1   20801  Cristiano Ronaldo   33    Portugal       94         94
# 2  190871          Neymar Jr   26      Brazil       92         93
# 3  193080             De Gea   27       Spain       91         93
# 4  192985       K. De Bruyne   27     Belgium       91         92
# 5  183277          E. Hazard   27     Belgium       91         91
# 6  177003          L. Modrić   32     Croatia       91         91
# 7  176580          L. Suárez   31     Uruguay       91         91
# 8  155862       Sergio Ramos   32       Spain       91         91
# 9  200389           J. Oblak   25    Slovenia       90         93
#
#                   Club     Value   Wage Preferred Foot  \
# 0         FC Barcelona  110500.0  565.0           Left
# 1             Juventus   77000.0  405.0          Right
# 2  Paris Saint-Germain  118500.0  290.0          Right
# ...

# %%
data.sample()
# Out:
#            ID         Name  Age   Nationality  Overall  Potential     Club  \
# 11978  212971  N. Al Mousa   27  Saudi Arabia       64         66  Al Ahli
#
#        Value  Wage Preferred Foot  International Reputation  Skill Moves  \
# 11978  450.0   7.0          Right                       1.0          2.0
#
#       Position  Joined Contract Valid Until  Height  Weight  Release Clause  \
# 11978      CDM    2018           2022-01-01    5.75   154.0           799.0
#
#        Left  Right
# 11978     0      1

# %%
data[data['Name']=='Cristiano Ronaldo']
# Out:
#       ID               Name  Age Nationality  Overall  Potential      Club  \
# 1  20801  Cristiano Ronaldo   33    Portugal       94         94  Juventus
#
#      Value   Wage Preferred Foot  International Reputation  Skill Moves  \
# 1  77000.0  405.0          Right                       5.0          5.0
#
#   Position  Joined Contract Valid Until    Height  Weight  Release Clause  \
# 1       ST    2018           2022-01-01  6.166667   183.0        127100.0
#
#    Left  Right
# 1     0      1

# %%
data.groupby('Club')['Value'].max()
# Out:
# Club
#  SSV Jahn Regensburg      2300.0
# 1. FC Heidenheim 1846     5000.0
# 1. FC Kaiserslautern      2500.0
# 1. FC Köln               24000.0
# 1. FC Magdeburg           1900.0
#                           ...
# Zagłębie Sosnowiec         675.0
# Çaykur Rizespor          10500.0
# Örebro SK                 2700.0
# Östersunds FK             1400.0
# Śląsk Wrocław             1000.0
# Name: Value, Length: 651, dtype: float64

# %%
data[( data['Age']<=25) & (data['Position']== 'ST')]
# Out:
#            ID                Name  Age          Nationality  Overall  \
# 16     202126             H. Kane   24              England       89
# 43     201399           M. Icardi   25            Argentina       87
# 47     192505           R. Lukaku   25              Belgium       87
# 124    202556            M. Depay   24          Netherlands       84
# 156    230666       Gabriel Jesus   21               Brazil       83
# ...       ...                 ...  ...                  ...      ...
# 18177  238550           R. Roache   18  Republic of Ireland       48
# 18189  240160          A. Kaltner   18              Germany       47
# 18200  231381            J. Young   18             Scotland       47
# 18203  243165  N. Christoffersson   19               Sweden       47
# 18204  241638           B. Worman   16              England       47
#
#        Potential                Club    Value   Wage Preferred Foot  \
# 16            91   Tottenham Hotspur  83500.0  205.0          Right
# ...

# %%
data.sample()
# Out:
#           ID             Name  Age Nationality  Overall  Potential       Club  \
# 5055  227921  M. Pouraliganji   26        Iran       70         73  KAS Eupen
#
#        Value  Wage Preferred Foot  International Reputation  Skill Moves  \
# 5055  1800.0   7.0          Right                       1.0          3.0
#
#      Position  Joined Contract Valid Until    Height  Weight  Release Clause  \
# 5055      RCB    2018           2020-01-01  6.166667   163.0          2900.0
#
#       Left  Right
# 5055     0      1

# %%
data['Height'].max()
# Out:
# 6.75

# %%
data['Height'].min()
# Out:
# 5.083333333333333

# %%
data['Preferred Foot'].value_counts()
# Out:
# Right    13748
# Left      4159
# Name: Preferred Foot, dtype: int64

# %%
data[data['Nationality']=='Egypt']
# Out:
#            ID            Name  Age Nationality  Overall  Potential  \
# 26     209331        M. Salah   26       Egypt       88         89
# 752    226078       Trezeguet   23       Egypt       78         80
# 959    213051       M. Elneny   25       Egypt       77         79
# 1517   210648       A. Hegazi   27       Egypt       76         78
# 2241   210259       A. Hassan   25       Egypt       74         78
# 2334   233601        R. Sobhi   21       Egypt       74         79
# 3310   191005   A. Elmohamady   30       Egypt       72         72
# 3616   233600        A. Warda   24       Egypt       72         75
# 3929   212469       A. Ghazal   26       Egypt       72         75
# 4044   229404        A. Tarek   26       Egypt       71         74
# 4504   197300      A. El Said   32       Egypt       71         71
# 5944   197975        S. Morsy   26       Egypt       69         71
# 7102   212088  M. Abdul Shafy   33       Egypt       68         68
# ...

# %%
data.describe()
# Out:
#                   ID           Age       Overall     Potential          Value  \
# count   17907.000000  17907.000000  17907.000000  17907.000000   17907.000000
# mean   214286.938795     25.095605     66.239571     71.335232    2450.132909
# std     29885.734201      4.660388      6.926818      6.137251    5633.206685
# min        16.000000     16.000000     46.000000     48.000000      10.000000
# 25%    200257.500000     21.000000     62.000000     67.000000     325.000000
# 50%    221710.000000     25.000000     66.000000     71.000000     700.000000
# 75%    236512.500000     28.000000     71.000000     75.000000    2100.000000
# max    246620.000000     45.000000     94.000000     95.000000  118500.000000
#
#                Wage  International Reputation   Skill Moves        Joined  \
# count  17907.000000              17907.000000  17907.000000  17907.000000
# mean       9.887753                  1.113699      2.363042   2016.429553
# ...

# %%
data.sample()
# Out:
#           ID        Name  Age Nationality  Overall  Potential  \
# 5458  220362  K. Mahachi   24    Zimbabwe       70         73
#
#                  Club   Value  Wage Preferred Foot  International Reputation  \
# 5458  Orlando Pirates  2300.0   1.0          Right                       1.0
#
#       Skill Moves Position  Joined Contract Valid Until    Height  Weight  \
# 5458          3.0       LW    2018           2021-01-01  5.583333   134.0
#
#       Release Clause  Left  Right
# 5458          5000.0     0      1

# %%
plt.figure(figsize=(13,6))
labels=['Right' , 'Left']
plt.pie(data['Position'] ,labels=labels , autopct='%0.f%%')
plt.show()

# %%
data['Position'][data['Position']=='RM'].count()
# Out:
# 1114

# %%
data['Position'].unique()
# Out:
# array(['RF', 'ST', 'LW', 'GK', 'RCM', 'LF', 'RS', 'RCB', 'LCM', 'CB',
#        'LDM', 'CAM', 'CDM', 'LS', 'LCB', 'RM', 'LAM', 'LM', 'LB', 'RDM',
#        'RW', 'CM', 'RB', 'RAM', 'CF', 'RWB', 'LWB'], dtype=object)

# %%
np.size((data['Nationality'].unique()))
# Out:
# 163

# %%
x=data.groupby('Nationality').size().sort_values(ascending= False)
x.head(10).plot(kind='bar' , figsize=(12,6),color = sns.color_palette("magma"))

# %%
z=data['Club'].value_counts().sort_values(ascending=False).nlargest(5)
z.plot(kind='bar' , figsize=(12,6),color = sns.color_palette("viridis"))

# %%
data['Age'][data['Age']<20].count()
# Out:
# 2075

# %%
data.columns
# Out:
# Index(['ID', 'Name', 'Age', 'Nationality', 'Overall', 'Potential', 'Club',
#        'Value', 'Wage', 'Preferred Foot', 'International Reputation',
#        'Skill Moves', 'Position', 'Joined', 'Contract Valid Until', 'Height',
#        'Weight', 'Release Clause', 'Left', 'Right'],
#       dtype='object')

# %%
data[data['Joined']==2018].groupby('Club')['Release Clause'].max()
# Out:
# Club
#  SSV Jahn Regensburg      2100.0
# 1. FC Heidenheim 1846     2400.0
# 1. FC Kaiserslautern      4200.0
# 1. FC Köln               17900.0
# 1. FC Magdeburg           2300.0
#                           ...
# Zagłębie Sosnowiec         641.0
# Çaykur Rizespor          11000.0
# Örebro SK                  531.0
# Östersunds FK             1300.0
# Śląsk Wrocław             1100.0
# Name: Release Clause, Length: 651, dtype: float64

# %%
plt.bar(data['Age'],data['Value'] ,color='yellow')
plt.show()

# %%
data.sample(3)
# Out:
#           ID           Name  Age Nationality  Overall  Potential  \
# 7940  222533   Nuno Valente   26    Portugal       67         68
# 4560  236998  J. Léa Siliki   22      France       71         81
# 3342  201257      T. Moulin   28      France       72         73
#
#                     Club   Value  Wage Preferred Foot  \
# 7940  Vitória de Setúbal   875.0   3.0          Right
# 4560    Stade Rennais FC  3800.0  17.0           Left
# 3342      MKE Ankaragücü  2800.0  15.0          Right
#
#       International Reputation  Skill Moves Position  Joined  \
# 7940                       1.0          3.0       CM    2018
# 4560                       1.0          3.0       CM    2017
# 3342                       1.0          3.0      CDM    2018
#
#      Contract Valid Until  Height  Weight  Release Clause  Left  Right
# 7940           2021-01-01    5.75   150.0          1900.0     0      1
# 4560           2021-01-01    6.00   154.0          7900.0     1      0
# ...

# %%
plt.bar(data['Position'],data['Skill Moves'] ,color='red')
plt.show()
